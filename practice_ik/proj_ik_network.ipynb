# %% [markdown]
# ## Neural Network for IK
# - Generate position & orientation within ROM
# - Neural network to achieve goal pose
#     - Current state + Goal state input
#     - Actuator output (motor)
#     - choose gravity compensation

# %% [markdown]
# ### Full code pipeline
# - Declare MuJoCo environment & Simple Neural Network
# - Train loop
#     - Generate reference pose for single episode
#     - Terminate if reached or max episode done
#     - Calculate reward: L2 norm distance, distinguish position and orientation term?
# - Algorithm: SAC
#     - Use simple SAC structure

# %%
import numpy as np

import torch
import torch.nn as nn

import mujoco as mj
import mujoco_viewer
